# %% [markdown]
# # 我这不是一个笔记
# - 二级
# - 三级
# - 四级

# %%
def foo():
    print('hello xxx world')

# %%
# !pip install jieba
# Out:
# Requirement already satisfied: jieba in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (0.42.1)

# %%
import jieba

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (1.9.1.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: six>=1.5 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %% [markdown]
# # 中文分词库jieba

# %% [markdown]
# 官方github仓库
# https://github.com/fxsjy/jieba

# %% [markdown]
# 扩展阅读：对Python中文分词模块结巴分词算法过程的理解和分析 https://blog.csdn.net/rav009/article/details/12196623

# %%
import jieba 
import jieba.posseg as pseg  # 词性分析

# %% [markdown]
# paddle模式 百度的ai框架提供的支持

# %% [markdown]
# 安装paddle的支持 官方github上提到的pip install paddlepaddle-tiny有问题

# %%
# !pip install paddlepaddle
# Out:
# Requirement already satisfied: paddlepaddle in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (2.4.2)
# Requirement already satisfied: numpy>=1.13 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (1.24.3)
# Requirement already satisfied: astor in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (0.8.1)
# Requirement already satisfied: paddle-bfloat==0.1.7 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (0.1.7)
# Requirement already satisfied: Pillow in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (9.4.0)
# Requirement already satisfied: opt-einsum==3.3.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (3.3.0)
# Requirement already satisfied: six in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (1.16.0)
# Requirement already satisfied: requests>=2.20.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (2.27.1)
# Requirement already satisfied: decorator in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (5.1.1)
# Requirement already satisfied: protobuf<=3.20.0,>=3.1.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from paddlepaddle) (3.20.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.20.0->paddlepaddle) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.20.0->paddlepaddle) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from requests>=2.20.0->paddlepaddle) (3.4)

# %%
jieba.enable_paddle()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 jieba.enable_paddle()
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\jieba\_compat.py:46, in enable_paddle()
#      44 else:
#      45     try:
# ---> 46         import jieba.lac_small.predict as predict
#      47         default_logger.debug("Paddle enabled successfully......")
#      48         check_paddle_install['is_paddle_installed'] = True
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\jieba\lac_small\predict.py:43
#      41 with fluid.program_guard(infer_program, fluid.default_startup_program()):
#      42     with fluid.unique_name.guard():
# ---> 43         infer_ret = creator.create_model(dataset.vocab_size, dataset.num_labels, mode='infer')
#      44 infer_program = infer_program.clone(for_test=True)
#      45 place = fluid.CPUPlace()
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\jieba\lac_small\creator.py:32, in create_model(vocab_size, num_labels, mode)
#      29 """create lac model"""
#      31 # model's input data
# ---> 32 words = fluid.data(name='words', shape=[-1, 1], dtype='int64', lod_level=1)
#      33 targets = fluid.data(
#      34     name='targets', shape=[-1, 1], dtype='int64', lod_level=1)
#      36 # for inference process
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\paddle\fluid\wrapped_decorator.py:26, in wrap_decorator.<locals>.__impl__(func, *args, **kwargs)
#      23 @decorator.decorator
#      24 def __impl__(func, *args, **kwargs):
#      25     wrapped_func = decorator_func(func)
# ---> 26     return wrapped_func(*args, **kwargs)
#
# File ~\anaconda3\envs\pytorch\lib\site-packages\paddle\fluid\framework.py:554, in _static_only_.<locals>.__impl__(*args, **kwargs)
#     553 def __impl__(*args, **kwargs):
# --> 554     assert not _non_static_mode(), (
#     555         "In PaddlePaddle 2.x, we turn on dynamic graph mode by default, and '%s()' is only supported in static graph mode. So if you want to use this api, please call 'paddle.enable_static()' before this api to enter static graph mode."
#     556         % func.__name__
#     557     )
#     558     return func(*args, **kwargs)
#
# AssertionError: In PaddlePaddle 2.x, we turn on dynamic graph mode by default, and 'data()' is only supported in static graph mode. So if you want to use this api, please call 'paddle.enable_static()' before this api to enter static graph mode.

# %% [markdown]
# ## 分词

# %% [markdown]
# * 全模式：所有可能的拆分方式都分出来 出现很多重叠
# * 精确模式：精确地拆分句子 不允许重叠

# %%
seg_list = jieba.cut("今天真热", cut_all=False)
seg_list
print(", ".join(seg_list))
# Out:
# Building prefix dict from the default dictionary ...
# [2023-05-27 12:57:35,514] [   DEBUG] __init__.py:113 - Building prefix dict from the default dictionary ...
# Dumping model to file cache C:\Users\MENGYA~1\AppData\Local\Temp\jieba.cache
# [2023-05-27 12:57:36,057] [   DEBUG] __init__.py:146 - Dumping model to file cache C:\Users\MENGYA~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.586 seconds.
# [2023-05-27 12:57:36,102] [   DEBUG] __init__.py:164 - Loading model cost 0.586 seconds.
# Prefix dict has been built successfully.
# [2023-05-27 12:57:36,103] [   DEBUG] __init__.py:166 - Prefix dict has been built successfully.
# 今天, 真热

# %%
strs=["我来到北京清华大学","乒乓球拍卖完了","中国科学技术大学"]
for str1 in strs:
    seg_list = jieba.cut(str1) # 使用paddle模式
    print("Paddle Mode: " + '/'.join(list(seg_list)))

seg_list = jieba.cut("我来到北京清华大学", cut_all=True)
print("Full Mode: " + "/ ".join(seg_list))  # 全模式

seg_list = jieba.cut("我来到北京清华大学", cut_all=False)
print("Default Mode: " + "/ ".join(seg_list))  # 精确模式

seg_list = jieba.cut("他来到了网易杭研大厦")  # 默认是精确模式
print(", ".join(seg_list))

seg_list = jieba.cut_for_search("小明硕士毕业于中国科学院计算所，后在日本京都大学深造")  # 搜索引擎模式
print(", ".join(seg_list))
# Out:
# Paddle Mode: 我/来到/北京/清华大学
# Paddle Mode: 乒乓球/拍卖/完/了
# Paddle Mode: 中国/科学技术/大学
# Full Mode: 我/ 来到/ 北京/ 清华/ 清华大学/ 华大/ 大学
# Default Mode: 我/ 来到/ 北京/ 清华大学
# 他, 来到, 了, 网易, 杭研, 大厦
# 小明, 硕士, 毕业, 于, 中国, 科学, 学院, 科学院, 中国科学院, 计算, 计算所, ，, 后, 在, 日本, 京都, 大学, 日本京都大学, 深造

# %% [markdown]
# ## 词性分析

# %%
words = pseg.cut("一片寂静之中，只听得蹄声嗒嗒，车轮在石板上隆隆滚动",use_paddle=True)
for word, flag in words:
     print('%s %s' % (word, flag),end=' ')
# Out:
# 一片 m 寂静 a 之中 r ， x 只 d 听 v 得 ud 蹄声 n 嗒 o 嗒 o ， x 车轮 n 在 p 石板 n 上 f 隆隆 o 滚动 v

# %%
words
# Out:
# <generator object cut at 0x000001E158E684A0>

# %%
words = pseg.cut("一片寂静之中，只听得蹄声嗒嗒，车轮在石板上隆隆滚动",use_paddle=True)
type(words)
# Out:
# generator

# %%
temp = next(words)
type(temp)
# Out:
# jieba.posseg.pair

# %% [markdown]
# 分词之后是jieba特有的pair对象 赋值类似于元祖 但是没有索引

# %%
temp
# Out:
# pair('一片', 'm')

# %%
a,b = temp

# %%
print(a)
print(b)
# Out:
# 一片
# m

# %% [markdown]
# <table>
# <thead>
# <tr>
# <th>标签</th>
# <th>含义</th>
# <th>标签</th>
# <th>含义</th>
# <th>标签</th>
# <th>含义</th>
# <th>标签</th>
# <th>含义</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>n</td>
# <td>普通名词</td>
# <td>f</td>
# <td>方位名词</td>
# <td>s</td>
# <td>处所名词</td>
# <td>t</td>
# <td>时间</td>
# </tr>
# <tr>
# <td>nr</td>
# <td>人名</td>
# <td>ns</td>
# <td>地名</td>
# <td>nt</td>
# <td>机构名</td>
# <td>nw</td>
# <td>作品名</td>
# </tr>
# <tr>
# <td>nz</td>
# <td>其他专名</td>
# <td>v</td>
# <td>普通动词</td>
# <td>vd</td>
# <td>动副词</td>
# <td>vn</td>
# <td>名动词</td>
# </tr>
# <tr>
# <td>a</td>
# <td>形容词</td>
# <td>ad</td>
# <td>副形词</td>
# <td>an</td>
# <td>名形词</td>
# <td>d</td>
# <td>副词</td>
# </tr>
# <tr>
# <td>m</td>
# <td>数量词</td>
# <td>q</td>
# <td>量词</td>
# <td>r</td>
# <td>代词</td>
# <td>p</td>
# <td>介词</td>
# </tr>
# <tr>
# <td>c</td>
# <td>连词</td>
# <td>u</td>
# <td>助词</td>
# <td>xc</td>
# <td>其他虚词</td>
# <td>w</td>
# <td>标点符号</td>
# </tr>
# <tr>
# <td>PER</td>
# <td>人名</td>
# <td>LOC</td>
# <td>地名</td>
# <td>ORG</td>
# <td>机构名</td>
# <td>TIME</td>
# <td>时间</td>
# </tr>
# </tbody>
# </table>

# %%
# 滤出所有名词
def foo(flag,sort=['n']):
    if flag in sort:
        return True
    return False

# %%
words = pseg.cut("一片寂静之中，只听得蹄声嗒嗒，车轮在石板上隆隆滚动",use_paddle=True)  # 生成器

for word,flag in words:
    if foo(flag):
        print(word)
# Out:
# 蹄声
# 车轮
# 石板

# %%
words = pseg.cut("一片寂静之中，只听得蹄声嗒嗒，车轮在石板上隆隆滚动",use_paddle=True)  # 生成器

[word for word,flag in words if foo(flag)]
# Out:
# ['蹄声', '车轮', '石板']

# %% [markdown]
# ## 停用词去除和词云制作

# %% [markdown]
# 读一本金庸小说进来

# %%
import re
strs = (re.sub('[^\u4e00-\u9fa50-9]',' ',strs))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 2
#       1 import re
# ----> 2 strs = (re.sub('[^\u4e00-\u9fa50-9]',' ',strs))
#
# File ~\anaconda3\envs\pytorch\lib\re.py:210, in sub(pattern, repl, string, count, flags)
#     203 def sub(pattern, repl, string, count=0, flags=0):
#     204     """Return the string obtained by replacing the leftmost
#     205     non-overlapping occurrences of the pattern in string by the
#     206     replacement repl.  repl can be either a string or a callable;
#     207     if a string, backslash escapes in it are processed.  If it is
#     208     a callable, it's passed the Match object and must return
#     209     a replacement string to be used."""
# --> 210     return _compile(pattern, flags).sub(repl, string, count)
#
# TypeError: expected string or bytes-like object

# %%
with open('.\金庸-天龙八部txt精校版.txt','r') as fp:
    strs = fp.read()

len(strs)
# Out:
# 1283405

# %%
words = pseg.cut(strs[10000:50000])  # 生成器
N = [word for word,flag in words if foo(flag,['v'])]

# %%
len(N)
# Out:
# 5042

# %%
'少女' in N
# Out:
# False

# %% [markdown]
# 停用词处理

# %%
# 读入停用词 做成list
def get_stopwords_list():
    #按行制作list 并且去掉行首位的空格
    stopwords = [line.strip() for line in open('./baidu_stopwords.txt',encoding='UTF-8').readlines()]  
    return stopwords

# %%
# 删除停用词
def remove_stopwords(sentence_list, stopwords_list):
    # 去停用词
    res = []
    for word in sentence_list:
        if word not in stopwords_list:
#             word = re.sub(r'[0123456789，。.\s]+', '', word)  # 去掉数字标点和空格
            res.append(word)
    return res

# %%
wordlist = remove_stopwords(N, get_stopwords_list())
len(wordlist)
# Out:
# 3886

# %%
wordlist
# Out:
# ['吃',
#  '无',
#  '深交',
#  '瞧',
#  '会',
#  '笑',
#  '定',
#  '出于',
#  '无意',
#  '饿',
#  '计较',
#  '得罪',
#  '不算',
#  '扫',
#  '笑',
#  '请教',
#  '请教',
#  '抽出',
#  '倒转',
#  '拱手',
#  '誉道',
#  '请',
#  '练',
#  '瞧',
#  '坐在',
#  '起身',
#  '涨',
#  '说',
#  '去',
#  '想',
#  '练',
#  '练',
#  '向来',
#  '爱',
#  '瞧',
#  '使',
#  '不妨',
#  '瞧',
#  '喝道',
#  '挥',
#  '摇',
#  '摇头',
#  '说道',
#  '怕',
#  '输',
#  '怕',
#  '说',
#  '说',
#  '犹如',
#  '听',
#  '忍不住',
#  '笑',
#  '占',
#  '笑',
#  '扫',
#  '无遗',
#  '伸剑',
#  '喝道',
#  '装傻',
#  '送',
#  '刺入',
#  '露',
#  '说道',
#  '装傻',
#  '活得',
#  '受',
#  '指使',
#  '直说',
#  '霸霸',
#  '爱',
#  '瞧',
#  '打架',
#  '住',
#  '喜',
#  '喜',
#  '离苦',
#  '获',
#  '喜',
#  '舍',
#  '派',
#  '说',
#  '回收',
#  '挥出',
#  '侧',
#  '闪避',
#  '缩回',
#  '肿',
#  '吃',
#  '料想',
#  '知',
#  '掌',
#  '避开',
#  '装傻',
#  '玩弄',
#  '决无',
#  '出',
#  '掌',
#  '得手',
#  '呆',
#  '抓住',
#  '提起',
#  '喝道',
#  '了不起',
#  '知',
#  '摔落',
#  '滚',
#  '撞',
#  '不忍',
#  '抢过去',
#  '伸手',
#  '扶',
#  '说道',
#  '厮混',
#  '了摸',
#  '说道',
#  '打架',
#  '砍',
#  '杀',
#  '好看',
#  '瞧',
#  '好玩',
#  '再见',
#  '再见',
#  '走',
#  '纵身',
#  '跃出',
#  '拦',
#  '说道',
#  '走',
#  '说',
#  '看',
#  '看',
#  '走',
#  '磕',
#  '响头',
#  '说',
#  '放屁',
#  '放屁',
#  '伸拳',
#  '击去',
#  '夹',
#  '不识',
#  '避让',
#  '缠住',
#  '腻',
#  '缠',
#  '吃',
#  '缩手',
#  '只见',
#  '缠',
#  '惊呼',
#  '挥',
#  '振',
#  '缠',
#  '说',
#  '甩',
#  '不脱',
#  '变',
#  '伸手',
#  '插入',
#  '掏摸',
#  '掏',
#  '不到',
#  '急',
#  '解衣',
#  '听',
#  '笑',
#  '只见',
#  '坐在',
#  '抓',
#  '花',
#  '显得',
#  '握',
#  '许长',
#  '呈',
#  '惧怕',
#  '仰视',
#  '听到',
#  '大叫',
#  '大嚷',
#  '惊呼',
#  '转眼',
#  '去',
#  '瞧',
#  '抬起',
#  '了头',
#  '见',
#  '荡',
#  '荡',
#  '坐在',
#  '好玩',
#  '救',
#  '还手',
#  '还手',
#  '听',
#  '叫唤',
#  '只见',
#  '手执',
#  '掉',
#  '显是',
#  '缠',
#  '挥剑',
#  '斩',
#  '死',
#  '上身',
#  '脱光',
#  '游走',
#  '反手',
#  '捉',
#  '抓',
#  '抓',
#  '不到',
#  '喝道',
#  '站',
#  '别动',
#  '呆',
#  '只见',
#  '闪',
#  '出',
#  '没瞧',
#  '出手',
#  '斩断',
#  '喝彩',
#  '干吗',
#  '弄死',
#  '可要',
#  '不知',
#  '爬到',
#  '没',
#  '察觉',
#  '注视',
#  '不知',
#  '伏',
#  '丢',
#  '穿着',
#  '绣',
#  '打扮',
#  '跳下来',
#  '跳下来',
#  '摔坏',
#  '去',
#  '忍不住',
#  '想',
#  '去',
#  '会',
#  '爬',
#  '赔',
#  '说话',
#  '去',
#  '捉',
#  '见',
#  '玩弄',
#  '来头',
#  '忍让',
#  '倒',
#  '说',
#  '去',
#  '捉',
#  '瞧瞧',
#  '跳下来',
#  '可要',
#  '拉',
#  '笑',
#  '试试看',
#  '拉',
#  '算',
#  '好手',
#  '闹着玩',
#  '请',
#  '派',
#  '抓',
#  '没',
#  '发话',
#  '赔',
#  '瞧瞧',
#  '掏出',
#  '掷',
#  '去',
#  '伸手',
#  '去',
#  '接',
#  '忙',
#  '避开',
#  '扭身',
#  '扑',
#  '看清',
#  '奔行',
#  '去',
#  '急抓',
#  '出手',
#  '抓',
#  '急挥',
#  '抓',
#  '乱打',
#  '游走',
#  '得紧',
#  '上身',
#  '抓',
#  '听',
#  '吹',
#  '动',
#  '扑到',
#  '扫去',
#  '急抓',
#  '奔到',
#  '插入',
#  '踏上',
#  '递',
#  '出',
#  '奔到',
#  '挺',
#  '刺去',
#  '扭动',
#  '奔到',
#  '刺到',
#  '叹服',
#  '递',
#  '毁',
#  '暗服',
#  '招',
#  '渡劫',
#  '刷刷',
#  '刷刷',
#  '连出',
#  '招',
#  '蹿',
#  '不见',
#  '呆',
#  '只见',
#  '抓',
#  '乱摸',
#  '钻入',
#  '拍手',
#  '说道',
#  '露出',
#  '生满',
#  '爱',
#  '欺侮',
#  '脱',
#  '瞧',
#  '羞',
#  '呼',
#  '听话',
#  '爬',
#  '钻入',
#  '不肯',
#  '脱',
#  '跳',
#  '拍',
#  '大叫',
#  '直奔',
#  '奔到',
#  '抢进',
#  '撞',
#  '入',
#  '后退',
#  '进来',
#  '一跤',
#  '摔倒',
#  '失声',
#  '顾不得',
#  '爬',
#  '爬',
#  '忙',
#  '抢',
#  '扶起',
#  '爬到',
#  '要紧',
#  '大叫',
#  '忙',
#  '去',
#  '抓',
#  '摔倒',
#  '笑',
#  '说道',
#  '整得',
#  '够',
#  '呼叫',
#  '钻',
#  '上',
#  '奔到',
#  '动',
#  '回到',
#  '赞道',
#  '抓',
#  '倒',
#  '提',
#  '晃动',
#  '抓住',
#  '吃',
#  '看',
#  '见',
#  '吃',
#  '完',
#  '钻入',
#  '扶起',
#  '惊叫',
#  '抢上',
#  '见',
#  '睁',
#  '愤恨',
#  '没了',
#  '惊',
#  '忙施',
#  '推拿',
#  '知',
#  '撞',
#  '没能',
#  '避开',
#  '撞',
#  '毙命',
#  '定',
#  '进来',
#  '身受',
#  '忙解',
#  '查伤',
#  '解开',
#  '只见',
#  '写',
#  '帮',
#  '诛灭',
#  '惊呼',
#  '写',
#  '腐蚀',
#  '深陷',
#  '凝视',
#  '振',
#  '喝道',
#  '瞧',
#  '帮',
#  '诛灭',
#  '诛灭',
#  '帮',
#  '报',
#  '看',
#  '无',
#  '喝道',
#  '瞧瞧',
#  '去',
#  '应声',
#  '出',
#  '去',
#  '围住',
#  '牵涉',
#  '做',
#  '沉吟',
#  '不知',
#  '帮',
#  '结下',
#  '惨亡',
#  '哽咽',
#  '采药',
#  '帮',
#  '求见',
#  '采',
#  '采药',
#  '帮',
#  '采药',
#  '为生',
#  '不让',
#  '帮',
#  '便是',
#  '没',
#  '去',
#  '传下',
#  '违犯',
#  '放入',
#  '摸',
#  '出',
#  '吃',
#  '誉',
#  '掷',
#  '去',
#  '笑',
#  '吃',
#  '不吃',
#  '没',
#  '上不来',
#  '解',
#  '抓住',
#  '拉',
#  '笑',
#  '试试看',
#  '摔',
#  '死',
#  '挂到',
#  '伸手',
#  '握住',
#  '抓紧',
#  '提',
#  '拉扯',
#  '拉',
#  '听话',
#  '摸出',
#  '捧',
#  '润滑',
#  '瞧',
#  '可爱',
#  '摸摸',
#  '摸',
#  '抚摸',
#  '觉着',
#  '钻入',
#  '没',
#  '提防',
#  '急缩',
#  '没坐',
#  '摔跌',
#  '抓住',
#  '拉',
#  '靠近',
#  '笑',
#  '奇怪',
#  '欺侮',
#  '相告',
#  '听',
#  '奔进',
#  '穿',
#  '回',
#  '上身',
#  '光着',
#  '颇显',
#  '走',
#  '帮',
#  '聚集',
#  '把守',
#  '说道',
#  '见',
#  '敢',
#  '想',
#  '诛灭',
#  '没',
#  '写',
#  '好生',
#  '无礼',
#  '说',
#  '呈',
#  '见',
#  '信封',
#  '写',
#  '接信',
#  '说道',
#  '拆来',
#  '瞧瞧',
#  '拆开',
#  '信封',
#  '抽出',
#  '要死',
#  '信封',
#  '有毒',
#  '听',
#  '读道',
#  '帮',
#  '直呼',
#  '读',
#  '略过',
#  '念',
#  '限',
#  '折断',
#  '退出',
#  '帮',
#  '夸下',
#  '倒',
#  '站',
#  '忙',
#  '伸手',
#  '扶',
#  '抢上',
#  '伸',
#  '拦',
#  '震出',
#  '喝道',
#  '有毒',
#  '别碰',
#  '只见',
#  '不住',
#  '抽搐',
#  '拿信',
#  '成',
#  '死去',
#  '接连',
#  '死',
#  '好手',
#  '帮',
#  '嗔道',
#  '有毒',
#  '笑',
#  '下毒',
#  '得紧',
#  '瞧',
#  '只能',
#  '无知',
#  '听见',
#  '只见',
#  '咬',
#  '穿着',
#  '不住',
#  '晃荡',
#  '瞧',
#  '去',
#  '不见',
#  '侧',
#  '看',
#  '信封',
#  '闪动',
#  '抬头',
#  '说',
#  '泄漏',
#  '听到',
#  '说道',
#  '笑',
#  '不上',
#  '说',
#  '知',
#  '查',
#  '便是',
#  '说',
#  '听',
#  '娇',
#  '擅于',
#  '会',
#  '没',
#  '出',
#  '推想',
#  '请',
#  '帮',
#  '说',
#  '杀',
#  '笑',
#  '杀',
#  '帮',
#  '杀',
#  '听到',
#  '赶着',
#  '瞧瞧',
#  '使毒',
#  '斗不过',
#  '帮',
#  '正说',
#  '拚',
#  '加上',
#  '聘请',
#  '作',
#  '好手',
#  '决不会',
#  '帮',
#  '解毒',
#  '听',
#  '死',
#  '看',
#  '开心',
#  '听到',
#  '惯',
#  '回答',
#  '问',
#  '吃',
#  '不吃',
#  '在外',
#  '不吃',
#  '炒',
#  '吃',
#  '试试看',
#  '说',
#  '抓',
#  '塞',
#  '吃',
#  '好吃',
#  '拂',
#  '送入',
#  '略加',
#  '辨味',
#  '回甘',
#  '生',
#  '吃',
#  '放在',
#  '下吐',
#  '出',
#  '乱飞',
#  '避开',
#  '问',
#  '听到',
#  '能见',
#  '告',
#  '探听',
#  '只得',
#  '听',
#  '帮',
#  '说起',
#  '怔',
#  '说道',
#  '倒',
#  '没',
#  '听见',
#  '听',
#  '说',
#  '回答',
#  '抢',
#  '不用',
#  '做戏',
#  '不肯',
#  '说',
#  '说道',
#  '想',
#  '帮',
#  '照见',
#  '说',
#  '说',
#  '帮结',
#  '干吗',
#  '杀',
#  '已成',
#  '想',
#  '透露',
#  '说',
#  '抓下',
#  '强加',
#  '拷问',
#  '请',
#  '详加',
#  '奉告',
#  '荡',
#  '荡',
#  '说道',
#  '详加',
#  '奉告',
#  '倒',
#  '不用',
#  '信得',
#  '说',
#  '脸现',
#  '收敛',
#  '说道',
#  '帮要',
#  '采药',
#  '答允',
#  '偷采',
#  '撞见',
#  '出言',
#  '说道',
#  '来不得',
#  '买下',
#  '便动',
#  '起手',
#  '下手',
#  '没',
#  '留情',
#  '杀',
#  '便是',
#  '结下',
#  '动',
#  '欠下',
#  '要采',
#  '倒',
#  '谅',
#  '说',
#  '结仇',
#  '说',
#  '捉',
#  '闪电',
#  '吃',
#  '闪电',
#  '奔跑',
#  '闪电',
#  '闪电',
#  '怪',
#  '打岔',
#  '正说',
#  '要紧',
#  '斥责',
#  '不肯',
#  '说',
#  '誉道',
#  '闪电',
#  '爱',
#  '吃',
#  '不吃',
#  '听',
#  '听',
#  '吓人',
#  '吓人',
#  '咬',
#  '咬',
#  '说',
#  '伸入',
#  '抚摸',
#  '说',
#  '笑',
#  '找',
#  '听',
#  '走',
#  '说道',
#  '杀',
#  '占',
#  '帮',
#  '听说',
#  '杀',
#  '倒',
#  '好玩',
#  '蹲',
#  '听',
#  '说',
#  '奉',
#  '占',
#  '说',
#  '对望',
#  '帮要',
#  '奉',
#  '听到',
#  '实',
#  '不知',
#  '帮',
#  '奉',
#  '为难',
#  '想到',
#  '帮',
#  '奉令',
#  '没',
#  '听说',
#  '增',
#  '皱起',
#  '吃',
#  '说道',
#  '听',
#  '说道',
#  '帮主',
#  '解得',
#  '拚着',
#  '身受',
#  '去',
#  '采',
#  '叹',
#  '说道',
#  '生死',
#  '符',
#  '没法',
#  '解得',
#  '生死',
#  '符',
#  '减轻',
#  '求生不得',
#  '说',
#  '走',
#  '说',
#  '够',
#  '不答',
#  '了不起',
#  '帮',
#  '帮主',
#  '治病',
#  '止痛',
#  '存心',
#  '占',
#  '听见',
#  '伸出',
#  '穿',
#  '挺身',
#  '惊呼',
#  '带',
#  '挽',
#  '说道',
#  '瞧瞧',
#  '去',
#  '看',
#  '帮',
#  '抢上',
#  '说道',
#  '请问',
#  '说道',
#  '生死',
#  '符',
#  '求生不得',
#  '问',
#  '霸霸',
#  '问',
#  '就算',
#  '决不会',
#  '说',
#  '实不愿',
#  '听',
#  '含有',
#  '关连',
#  '存亡',
#  '问',
#  '晃动',
#  '拦',
#  '说道',
#  '帮',
#  '在外',
#  '闪失',
#  '请来',
#  '不知',
#  '帮杀',
#  '决不会',
#  '怪',
#  '保护',
#  '说',
#  '挽',
#  '走',
#  '拔出',
#  '说道',
#  '摇头',
#  '说道',
#  '不肯',
#  '说',
#  '杀',
#  '斜',
#  '横',
#  '拦住',
#  '誉道',
#  '杀',
#  '说',
#  '摇手',
#  '说',
#  '杀死',
#  '共享',
#  '吃',
#  '挨',
#  '说',
#  '不枉',
#  '相识',
#  '走',
#  '拉',
#  '走',
#  '去',
#  '闪烁',
#  '恍如',
#  '不见',
#  '抖',
#  '倒',
#  '无',
#  '走出',
#  '抢上',
#  '抓住',
#  '拍',
#  '动',
#  '闪电',
#  '跃出',
#  '扑',
#  '忙',
#  '伸手',
#  '去',
#  '抓',
#  '闪电',
#  '动',
#  '闪电',
#  '钻入',
#  '遭咬',
#  '大叫',
#  '跪',
#  '觉',
#  '有毒',
#  '抓紧',
#  '生怕',
#  '上行',
#  '抢上',
#  '去',
#  '扶',
#  '解药',
#  '刺死',
#  '笑',
#  '解药',
#  '去',
#  '采',
#  '煎',
#  '喝下去',
#  '没事',
#  '拦住',
#  '干吗',
#  '想',
#  '咬',
#  '说',
#  '摸出',
#  '闪电',
#  '捧',
#  '挽',
#  '誉向',
#  '走',
#  '见到',
#  '决避',
#  '不开',
#  '扑',
#  '咬',
#  '彷徨',
#  '瞧',
#  '走出',
#  '来到',
#  '闪电',
#  '出头',
#  '出',
#  '在外',
#  '守御',
#  '以防',
#  '帮来',
#  '攻',
#  '出得',
#  '没',
#  '遇上',
#  '闪电',
#  '不知',
#  '吃',
#  ...]

# %% [markdown]
# 词云库安装

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (1.9.1.1)
# Requirement already satisfied: pillow in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from wordcloud) (3.5.1)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (23.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\mengyan-zhishang\anaconda3\envs\pytorch\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import numpy as np
from PIL import Image

# %%
# 必须给个符号分隔开分词结果来形成字符串,否则不能绘制词云
wordstr = " ".join(wordlist)

# %%
wordcloud = WordCloud(
        # 设置字体，不指定就会出现乱码
        font_path=r'C:\Windows\Fonts\msjh.ttc',
        # 设置背景色
        background_color='white',
        # 最大字体
        max_font_size=80,
        # 最小字体
        min_font_size=20,
        mode='RGBA',
#         mask=np.array(Image.open( r'./pic/武侠.png'))
        #colormap='pink'
        )

# %%
wordcloud.generate(wordstr)

# %%
plt.figure("jinyong")
plt.imshow(wordcloud)
plt.axis("off")
plt.show()


wordcloud.to_file("./pic/cloud_result.png")
